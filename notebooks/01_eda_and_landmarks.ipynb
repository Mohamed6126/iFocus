# %%
import sys
sys.path.append("..")

from PIL import Image
from src.dataset import load_annotations
from src.utils import plot_landmarks

# %%
train_df = load_annotations("annotations_train.json")

# %%
print("Train split:\n", train_df["label"].value_counts())
sample = train_df.iloc[0]
img = Image.open(sample["image_path"])
print("Sample Image resolution:", img.size)

# %%
plot_landmarks(sample["image_path"], sample["landmarks"], sample["label"])
